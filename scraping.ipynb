# %%
# !pip install requests bs4 selenium
# Out:
# Requirement already satisfied: requests in /Users/arjunj/anaconda3/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: bs4 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (0.0.2)
# Requirement already satisfied: selenium in /Users/arjunj/anaconda3/lib/python3.11/site-packages (4.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from requests) (2024.7.4)
# Requirement already satisfied: beautifulsoup4 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from bs4) (4.12.3)
# Requirement already satisfied: trio~=0.17 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from selenium) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: typing_extensions~=4.9 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from urllib3<3,>=1.21.1->requests) (1.7.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/arjunj/anaconda3/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time

# %% [markdown]
# # Scraping MVP data

# %%
for i in range(1991, 2025):
    data = requests.get("https://www.basketball-reference.com/awards/awards_{}.html".format(i))
    with open("data/mvp/{}.html".format(i), "w+") as f:
        f.write(data.text)

# %%
list_of_dfs = []
for i in range(1991, 2025):
    html_file_path = 'data/mvp/{}.html'.format(i)
    with open(html_file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()
    
    soup = BeautifulSoup(html_content, 'html.parser')
    soup.find('tr', class_="over_header").decompose()
    table = soup.find('table', {'id': 'mvp'})
    
    if table:
        df = pd.read_html(StringIO(str(table)))[0]
        df["year"] = i
        list_of_dfs.append(df)
    else:
        print("Table not found in the HTML file.")

pd.concat(list_of_dfs).to_csv('mvps.csv')

# %% [markdown]
# # Chrome Driver + Selenium Set up

# %%
service = Service('/Users/arjunj/Desktop/sideProjects/nbaMvp/chromedriver-mac-arm64/chromedriver')
driver = webdriver.Chrome(service=service)

# %% [markdown]
# # scraping and parsing player stats and advanced stats data

# %%
for i in range(1991, 2025):
    driver.get("https://www.basketball-reference.com/leagues/NBA_{}_per_game.html".format(i))
    driver.execute_script("window.scrollTo(1,10000)")
    time.sleep(2)
    html = driver.page_source
    with open("data/playerStats/{}.html".format(i), "w+") as f:
        f.write(html)

# %%
list_of_dfs = []
for i in range(1991, 2025):
    html_file_path = 'data/playerStats/{}.html'.format(i)
    with open(html_file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()
    
    soup = BeautifulSoup(html_content, 'html.parser')
    soup.find('tr', class_="thead").decompose()
    table = soup.find('table', {'id': 'per_game_stats'})
    
    if table:
        df = pd.read_html(StringIO(str(table)))[0]
        df["year"] = i
        list_of_dfs.append(df)
    else:
        print("Table not found in the HTML file.")

pd.concat(list_of_dfs).to_csv('playerStats.csv')

# %%
for i in range(1991, 2025):
    driver.get("https://www.basketball-reference.com/leagues/NBA_{}_advanced.html".format(i))
    driver.execute_script("window.scrollTo(1,10000)")
    time.sleep(1)
    html = driver.page_source
    with open("data/playerStatsAdvanced/{}.html".format(i), "w+") as f:
        f.write(html)

# %%
list_of_dfs = []
for i in range(1991, 2025):
    html_file_path = 'data/playerStatsAdvanced/{}.html'.format(i)
    with open(html_file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()
    
    soup = BeautifulSoup(html_content, 'html.parser')
    soup.find('tr', class_="thead").decompose()
    table = soup.find('table', {'id': 'advanced'})
    
    if table:
        df = pd.read_html(StringIO(str(table)))[0]
        df["year"] = i
        list_of_dfs.append(df)
    else:
        print("Table not found in the HTML file.")

pd.concat(list_of_dfs).to_csv('playerStatsAdvanced.csv')

# %% [markdown]
# # Scraping Team record data

# %%
for i in range(1991, 2025):
    data = requests.get("https://www.basketball-reference.com/leagues/NBA_{}_standings.html".format(i))
    with open("data/standings/{}.html".format(i), "w+") as f:
        f.write(data.text)

# %%
list_of_dfs = []
for i in range(1991, 2025):
    html_file_path = 'data/standings/{}.html'.format(i)
    with open(html_file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()
    
    soup = BeautifulSoup(html_content, 'html.parser')
    #soup.find('tr', class_="over_header").decompose()
    tableEast = soup.find('table', {'id': 'divs_standings_E'})
    tableWest = soup.find('table', {'id': 'divs_standings_W'})
    if tableEast and tableWest:
        dfEast = pd.read_html(StringIO(str(tableEast)))[0]
        dfEast = dfEast[~dfEast['W'].str.endswith('Division', na=False)]
        dfEast["year"] = i
        dfEast.rename(columns={'Eastern Conference': 'Team'}, inplace=True)
        dfWest = pd.read_html(StringIO(str(tableWest)))[0]
        dfWest = dfWest[~dfWest['W'].str.endswith('Division', na=False)]
        dfWest["year"] = i
        dfWest.rename(columns={'Western Conference': 'Team'}, inplace=True)
        
        list_of_dfs.append(pd.concat([dfWest, dfEast], ignore_index=True))
    else:
        print("Table not found in the HTML file.")


pd.concat(list_of_dfs).to_csv('standings.csv')
